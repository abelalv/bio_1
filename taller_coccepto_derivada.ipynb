# %% [markdown]
# # taller

# %% [markdown]
# * Explica con tus propias palabras qué es la derivada de una función en un punto.
#
# * ¿Cómo se interpreta geométricamente la derivada de una función en un punto?
#
# * Relaciona la derivada con el concepto de tasa de cambio instantánea. Proporciona un ejemplo práctico.
#
# * ¿Bajo qué condiciones una función no tiene derivada en un punto? Da ejemplos de funciones en las que no existe la derivada.
#
# ![image.png](attachment:image.png)
#
# * Calcula la derivada de $f(x) = x^2$ en $x = 3$ usando la definición de derivada como límite.
#
# * Calcula la derivada de $f(x) = \sqrt{x}$ en $x = 4$ usando la definición de derivada como límite.
#
# * Calcula la derivada de la función $f(x) = 2x + 5$ en cualquier punto usando la definición de derivada como límite. ¿Cuál es el resultado y qué significa?
#
# * ¿Es posible que una función tenga derivada en un punto donde no es continua? Explica tu respuesta.
#
# * Calcula la derivada de $f(x) = \frac{1}{x}$ en $x = 2$ utilizando la definición de derivada como límite.

# %% [markdown]
# * encuentre la derivada
#
# ![](figures/derivada.png)

# %% [markdown]
# * Haga coincidir el gráfico de cada función en (a) - (d) con el gráfico de su derivada en I-IV. Dé razones para sus elecciones.
#
#
# ![](figures/derivada2.png)
